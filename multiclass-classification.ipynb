# %%
import pandas as pd
import numpy as np

import seaborn as sns


from sklearn.metrics import accuracy_score, classification_report, mean_absolute_error
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Dataset consist of 30000 rows and 14 features
#
# Description of each feature is as follows
#
# 1. Random: An identifier for each record, likely indicating a random sample or batch (object type).
# 2. Average of chlorophyll in the plant (ACHP): The average chlorophyll content in the plant (float type).
# 3. Plant height rate (PHR): The rate of plant height growth (float type).
# 4. Average wet weight of the growth vegetative (AWWGV): The average wet weight of vegetative growth (float type).
# 5. Average leaf area of the plant (ALAP): The average leaf area of the plant (float type).
# 6. Average number of plant leaves (ANPL): The average number of leaves per plant (float type).
# 7. Average root diameter (ARD): The average diameter of the plant's roots (float type).
# 8. Average dry weight of the root (ADWR): The average dry weight of the plant's roots (float type).
# 9. Percentage of dry matter for vegetative growth (PDMVG): The percentage of dry matter in vegetative growth (float type).
# 10. Average root length (ARL): The average length of the plant's roots (float type).
# 11. Average wet weight of the root (AWWR): The average wet weight of the plant's roots (float type).
# 12. Average dry weight of vegetative plants (ADWV): The average dry weight of vegetative parts of the plant (float type).
# 13. Percentage of dry matter for root growth (PDMRG): The percentage of dry matter in root growth (float type).
# 14. Class: The class or category to which the plant record belongs (object type).

# %% [markdown]
# ## Data Loading

# %%
df = pd.read_csv("/kaggle/input/advanced-iot-agriculture-2024/Advanced_IoT_Dataset.csv")

# %%
df.head()
# Out:
#   Random   Average  of chlorophyll in the plant (ACHP)  \
# 0     R1                                     34.533468
# 1     R1                                     34.489028
# 2     R2                                     33.100405
# 3     R1                                     34.498319
# 4     R3                                     36.297008
#
#     Plant height rate (PHR)  \
# 0                 54.566983
# 1                 54.567692
# 2                 67.067344
# 3                 54.559049
# 4                 45.588894
#
#    Average wet weight of the growth vegetative (AWWGV)  \
# 0                                           1.147449
# 1                                           1.149530
# 2                                           1.104647
# 3                                           1.137759
# 4                                           1.363205
#
#    Average leaf area of the plant (ALAP)  \
# 0                            1284.229549
# 1                            1284.247744
# 2                            1009.208996
# 3                            1284.227623
# 4                             981.470310
#
#    Average number of plant leaves (ANPL)  Average root diameter (ARD)  \
# 0                               4.999713                    16.274918
# 1                               5.024259                    16.269452
# 2                               5.007652                    15.980760
# 3                               4.991501                    16.276710
# 4                               4.003682                    16.979894
#
#     Average dry weight of the root (ADWR)  \
# 0                                1.706810
# 1                                1.700930
# 2                                1.185391
# 3                                1.716396
# 4                                0.777428
#
#     Percentage of dry matter for vegetative growth (PDMVG)  \
# 0                                          18.399982
# 1                                          18.398289
# 2                                          19.398789
# 3                                          18.413613
# 4                                          31.423772
#
#    Average root length (ARL)  Average wet weight of the root (AWWR)  \
# 0                  19.739037                               2.949240
# 1                  19.758836                               2.943137
# 2                  20.840822                               2.861635
# 3                  19.736098                               2.946784
# 4                  17.331894                               2.766242
#
#     Average dry weight of vegetative plants (ADWV)  \
# 0                                         0.209251
# 1                                         0.216154
# 2                                         0.200113
# 3                                         0.223092
# 4                                         0.424172
#
#    Percentage of dry matter for root growth (PDMRG) Class
# 0                                         57.633906    SA
# 1                                         57.633697    SA
# 2                                         41.289875    SA
# 3                                         57.645661    SA
# 4                                         27.898619    SA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 14 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Random                                                   30000 non-null  object
#  1    Average  of chlorophyll in the plant (ACHP)             30000 non-null  float64
#  2    Plant height rate (PHR)                                 30000 non-null  float64
#  3   Average wet weight of the growth vegetative (AWWGV)      30000 non-null  float64
#  4   Average leaf area of the plant (ALAP)                    30000 non-null  float64
#  5   Average number of plant leaves (ANPL)                    30000 non-null  float64
#  6   Average root diameter (ARD)                              30000 non-null  float64
#  7    Average dry weight of the root (ADWR)                   30000 non-null  float64
#  8    Percentage of dry matter for vegetative growth (PDMVG)  30000 non-null  float64
#  9   Average root length (ARL)                                30000 non-null  float64
#  10  Average wet weight of the root (AWWR)                    30000 non-null  float64
#  11   Average dry weight of vegetative plants (ADWV)          30000 non-null  float64
#  12  Percentage of dry matter for root growth (PDMRG)         30000 non-null  float64
#  13  Class                                                    30000 non-null  object
# dtypes: float64(12), object(2)
# memory usage: 3.2+ MB

# %%
df.describe().T
# Out:
#                                                       count         mean  \
#  Average  of chlorophyll in the plant (ACHP)        30000.0    38.060575
#  Plant height rate (PHR)                            30000.0    59.020331
# Average wet weight of the growth vegetative (AW...  30000.0     1.247257
# Average leaf area of the plant (ALAP)               30000.0  1063.639833
# Average number of plant leaves (ANPL)               30000.0     3.944789
# Average root diameter (ARD)                         30000.0    16.285792
#  Average dry weight of the root (ADWR)              30000.0     1.000981
#  Percentage of dry matter for vegetative growth...  30000.0    22.674553
# Average root length (ARL)                           30000.0    18.071061
# Average wet weight of the root (AWWR)               30000.0     2.907011
#  Average dry weight of vegetative plants (ADWV)     30000.0     0.292094
# Percentage of dry matter for root growth (PDMRG)    30000.0    34.922184
#
#                                                            std         min  \
#  Average  of chlorophyll in the plant (ACHP)          4.441682   32.664004
#  Plant height rate (PHR)                             11.985213   37.020398
# Average wet weight of the growth vegetative (AW...    0.245989    0.848351
# Average leaf area of the plant (ALAP)               260.712823  658.488225
# Average number of plant leaves (ANPL)                 0.702537    2.959173
# Average root diameter (ARD)                           2.882793   11.075737
#  Average dry weight of the root (ADWR)                0.456292    0.241972
#  Percentage of dry matter for vegetative growth...    9.571091    8.021505
# Average root length (ARL)                             2.932830   12.359924
# Average wet weight of the root (AWWR)                 1.361928    1.126715
#  Average dry weight of vegetative plants (ADWV)       0.151516    0.038210
# Percentage of dry matter for root growth (PDMRG)      7.998132   23.632527
#
#                                                            25%          50%  \
#  Average  of chlorophyll in the plant (ACHP)         34.399604    36.575753
#  Plant height rate (PHR)                             51.059436    55.912058
# Average wet weight of the growth vegetative (AW...    1.064865     1.211328
# Average leaf area of the plant (ALAP)               875.501356  1009.249081
# Average number of plant leaves (ANPL)                 3.013099     3.998577
# Average root diameter (ARD)                          13.933350    16.248496
#  Average dry weight of the root (ADWR)                0.675892     0.833799
#  Percentage of dry matter for vegetative growth...   14.980983    21.954006
# Average root length (ARL)                            15.600294    18.477019
# Average wet weight of the root (AWWR)                 1.911408     2.818611
#  Average dry weight of vegetative plants (ADWV)       0.185512     0.246454
# Percentage of dry matter for root growth (PDMRG)     28.650713    33.372665
#
#                                                             75%          max
#  Average  of chlorophyll in the plant (ACHP)          42.300836    46.431668
#  Plant height rate (PHR)                              67.069465    77.040610
# Average wet weight of the growth vegetative (AW...     1.501692     1.775383
# Average leaf area of the plant (ALAP)               1243.866525  1751.031654
# Average number of plant leaves (ANPL)                  4.015829     5.037358
# Average root diameter (ARD)                           18.202577    23.325870
#  Average dry weight of the root (ADWR)                 1.313504     2.196556
#  Percentage of dry matter for vegetative growth...    27.711471    43.660373
# Average root length (ARL)                             20.365252    23.253049
# Average wet weight of the root (AWWR)                  3.254133     6.908923
#  Average dry weight of vegetative plants (ADWV)        0.407858     0.687470
# Percentage of dry matter for root growth (PDMRG)      39.137224    57.672004

# %%
df.isnull().sum()
# Out:
# Random                                                     0
#  Average  of chlorophyll in the plant (ACHP)               0
#  Plant height rate (PHR)                                   0
# Average wet weight of the growth vegetative (AWWGV)        0
# Average leaf area of the plant (ALAP)                      0
# Average number of plant leaves (ANPL)                      0
# Average root diameter (ARD)                                0
#  Average dry weight of the root (ADWR)                     0
#  Percentage of dry matter for vegetative growth (PDMVG)    0
# Average root length (ARL)                                  0
# Average wet weight of the root (AWWR)                      0
#  Average dry weight of vegetative plants (ADWV)            0
# Percentage of dry matter for root growth (PDMRG)           0
# Class                                                      0
# dtype: int64

# %%
num_cols=df.select_dtypes(exclude=["object"]).columns
print(num_cols)
# Out:
# Index([' Average  of chlorophyll in the plant (ACHP)',
#        ' Plant height rate (PHR)',
#        'Average wet weight of the growth vegetative (AWWGV)',
#        'Average leaf area of the plant (ALAP)',
#        'Average number of plant leaves (ANPL)', 'Average root diameter (ARD)',
#        ' Average dry weight of the root (ADWR)',
#        ' Percentage of dry matter for vegetative growth (PDMVG)',
#        'Average root length (ARL)', 'Average wet weight of the root (AWWR)',
#        ' Average dry weight of vegetative plants (ADWV)',
#        'Percentage of dry matter for root growth (PDMRG)'],
#       dtype='object')

# %%
df[num_cols].corr()
# Out:
#                                                      Average  of chlorophyll in the plant (ACHP)  \
#  Average  of chlorophyll in the plant (ACHP)                                            1.000000
#  Plant height rate (PHR)                                                               -0.013622
# Average wet weight of the growth vegetative (AW...                                      0.427460
# Average leaf area of the plant (ALAP)                                                  -0.401833
# Average number of plant leaves (ANPL)                                                  -0.385251
# Average root diameter (ARD)                                                            -0.415854
#  Average dry weight of the root (ADWR)                                                 -0.379075
#  Percentage of dry matter for vegetative growth...                                     -0.120607
# Average root length (ARL)                                                              -0.592119
# Average wet weight of the root (AWWR)                                                  -0.376681
#  Average dry weight of vegetative plants (ADWV)                                         0.115942
# Percentage of dry matter for root growth (PDMRG)                                        0.000107
#
#                                                      Plant height rate (PHR)  \
#  Average  of chlorophyll in the plant (ACHP)                       -0.013622
#  Plant height rate (PHR)                                            1.000000
# Average wet weight of the growth vegetative (AW...                  0.493050
# Average leaf area of the plant (ALAP)                               0.635731
# Average number of plant leaves (ANPL)                               0.090495
# Average root diameter (ARD)                                        -0.087562
#  Average dry weight of the root (ADWR)                             -0.052952
#  Percentage of dry matter for vegetative growth...                  0.514732
# Average root length (ARL)                                           0.202433
# Average wet weight of the root (AWWR)                               0.006415
#  Average dry weight of vegetative plants (ADWV)                     0.573550
# Percentage of dry matter for root growth (PDMRG)                   -0.088112
#
#                                                     Average wet weight of the growth vegetative (AWWGV)  \
#  Average  of chlorophyll in the plant (ACHP)                                                 0.427460
#  Plant height rate (PHR)                                                                     0.493050
# Average wet weight of the growth vegetative (AW...                                           1.000000
# Average leaf area of the plant (ALAP)                                                        0.266280
# Average number of plant leaves (ANPL)                                                       -0.104903
# Average root diameter (ARD)                                                                 -0.166862
#  Average dry weight of the root (ADWR)                                                      -0.096338
#  Percentage of dry matter for vegetative growth...                                           0.393870
# Average root length (ARL)                                                                   -0.215712
# Average wet weight of the root (AWWR)                                                       -0.059155
#  Average dry weight of vegetative plants (ADWV)                                              0.701240
# Percentage of dry matter for root growth (PDMRG)                                             0.000532
#
#                                                     Average leaf area of the plant (ALAP)  \
#  Average  of chlorophyll in the plant (ACHP)                                    -0.401833
#  Plant height rate (PHR)                                                         0.635731
# Average wet weight of the growth vegetative (AW...                               0.266280
# Average leaf area of the plant (ALAP)                                            1.000000
# Average number of plant leaves (ANPL)                                            0.404359
# Average root diameter (ARD)                                                      0.326802
#  Average dry weight of the root (ADWR)                                           0.399542
#  Percentage of dry matter for vegetative growth...                               0.391506
# Average root length (ARL)                                                        0.604169
# Average wet weight of the root (AWWR)                                            0.419564
#  Average dry weight of vegetative plants (ADWV)                                  0.366951
# Percentage of dry matter for root growth (PDMRG)                                -0.007883
#
#                                                     Average number of plant leaves (ANPL)  \
#  Average  of chlorophyll in the plant (ACHP)                                    -0.385251
#  Plant height rate (PHR)                                                         0.090495
# Average wet weight of the growth vegetative (AW...                              -0.104903
# Average leaf area of the plant (ALAP)                                            0.404359
# Average number of plant leaves (ANPL)                                            1.000000
# Average root diameter (ARD)                                                      0.512514
#  Average dry weight of the root (ADWR)                                           0.778143
#  Percentage of dry matter for vegetative growth...                               0.141591
# Average root length (ARL)                                                        0.537721
# Average wet weight of the root (AWWR)                                            0.528448
#  Average dry weight of vegetative plants (ADWV)                                 -0.002440
# Percentage of dry matter for root growth (PDMRG)                                 0.555486
#
#                                                     Average root diameter (ARD)  \
#  Average  of chlorophyll in the plant (ACHP)                          -0.415854
#  Plant height rate (PHR)                                              -0.087562
# Average wet weight of the growth vegetative (AW...                    -0.166862
# Average leaf area of the plant (ALAP)                                  0.326802
# Average number of plant leaves (ANPL)                                  0.512514
# Average root diameter (ARD)                                            1.000000
#  Average dry weight of the root (ADWR)                                 0.833025
#  Percentage of dry matter for vegetative growth...                    -0.116574
# Average root length (ARL)                                              0.722004
# Average wet weight of the root (AWWR)                                  0.963054
#  Average dry weight of vegetative plants (ADWV)                       -0.168133
# Percentage of dry matter for root growth (PDMRG)                      -0.144971
#
#                                                      Average dry weight of the root (ADWR)  \
#  Average  of chlorophyll in the plant (ACHP)                                     -0.379075
#  Plant height rate (PHR)                                                         -0.052952
# Average wet weight of the growth vegetative (AW...                               -0.096338
# Average leaf area of the plant (ALAP)                                             0.399542
# Average number of plant leaves (ANPL)                                             0.778143
# Average root diameter (ARD)                                                       0.833025
#  Average dry weight of the root (ADWR)                                            1.000000
#  Percentage of dry matter for vegetative growth...                               -0.187510
# Average root length (ARL)                                                         0.705628
# Average wet weight of the root (AWWR)                                             0.876905
#  Average dry weight of vegetative plants (ADWV)                                  -0.218848
# Percentage of dry matter for root growth (PDMRG)                                  0.344392
#
#                                                      Percentage of dry matter for vegetative growth (PDMVG)  \
#  Average  of chlorophyll in the plant (ACHP)                                                -0.120607
#  Plant height rate (PHR)                                                                     0.514732
# Average wet weight of the growth vegetative (AW...                                           0.393870
# Average leaf area of the plant (ALAP)                                                        0.391506
# Average number of plant leaves (ANPL)                                                        0.141591
# Average root diameter (ARD)                                                                 -0.116574
#  Average dry weight of the root (ADWR)                                                      -0.187510
#  Percentage of dry matter for vegetative growth...                                           1.000000
# Average root length (ARL)                                                                   -0.102200
# Average wet weight of the root (AWWR)                                                       -0.195834
#  Average dry weight of vegetative plants (ADWV)                                              0.913545
# Percentage of dry matter for root growth (PDMRG)                                             0.032238
#
#                                                     Average root length (ARL)  \
#  Average  of chlorophyll in the plant (ACHP)                        -0.592119
#  Plant height rate (PHR)                                             0.202433
# Average wet weight of the growth vegetative (AW...                  -0.215712
# Average leaf area of the plant (ALAP)                                0.604169
# Average number of plant leaves (ANPL)                                0.537721
# Average root diameter (ARD)                                          0.722004
#  Average dry weight of the root (ADWR)                               0.705628
#  Percentage of dry matter for vegetative growth...                  -0.102200
# Average root length (ARL)                                            1.000000
# Average wet weight of the root (AWWR)                                0.771567
#  Average dry weight of vegetative plants (ADWV)                     -0.183255
# Percentage of dry matter for root growth (PDMRG)                    -0.110905
#
#                                                     Average wet weight of the root (AWWR)  \
#  Average  of chlorophyll in the plant (ACHP)                                    -0.376681
#  Plant height rate (PHR)                                                         0.006415
# Average wet weight of the growth vegetative (AW...                              -0.059155
# Average leaf area of the plant (ALAP)                                            0.419564
# Average number of plant leaves (ANPL)                                            0.528448
# Average root diameter (ARD)                                                      0.963054
#  Average dry weight of the root (ADWR)                                           0.876905
#  Percentage of dry matter for vegetative growth...                              -0.195834
# Average root length (ARL)                                                        0.771567
# Average wet weight of the root (AWWR)                                            1.000000
#  Average dry weight of vegetative plants (ADWV)                                 -0.196339
# Percentage of dry matter for root growth (PDMRG)                                -0.131328
#
#                                                      Average dry weight of vegetative plants (ADWV)  \
#  Average  of chlorophyll in the plant (ACHP)                                               0.115942
#  Plant height rate (PHR)                                                                   0.573550
# Average wet weight of the growth vegetative (AW...                                         0.701240
# Average leaf area of the plant (ALAP)                                                      0.366951
# Average number of plant leaves (ANPL)                                                     -0.002440
# Average root diameter (ARD)                                                               -0.168133
#  Average dry weight of the root (ADWR)                                                    -0.218848
#  Percentage of dry matter for vegetative growth...                                         0.913545
# Average root length (ARL)                                                                 -0.183255
# Average wet weight of the root (AWWR)                                                     -0.196339
#  Average dry weight of vegetative plants (ADWV)                                            1.000000
# Percentage of dry matter for root growth (PDMRG)                                           0.004696
#
#                                                     Percentage of dry matter for root growth (PDMRG)
#  Average  of chlorophyll in the plant (ACHP)                                                0.000107
#  Plant height rate (PHR)                                                                   -0.088112
# Average wet weight of the growth vegetative (AW...                                          0.000532
# Average leaf area of the plant (ALAP)                                                      -0.007883
# Average number of plant leaves (ANPL)                                                       0.555486
# Average root diameter (ARD)                                                                -0.144971
#  Average dry weight of the root (ADWR)                                                      0.344392
#  Percentage of dry matter for vegetative growth...                                          0.032238
# Average root length (ARL)                                                                  -0.110905
# Average wet weight of the root (AWWR)                                                      -0.131328
#  Average dry weight of vegetative plants (ADWV)                                             0.004696
# Percentage of dry matter for root growth (PDMRG)                                            1.000000

# %%
# sns.heatmap(df[num_cols].corr(), annot=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
df["Class"]=encoder.fit_transform(df["Class"])

# %%
df["Class"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 29995    5
# 29996    5
# 29997    5
# 29998    5
# 29999    5
# Name: Class, Length: 30000, dtype: int64

# %%
#define dependent and independent variable
x=df.drop(["Class","Random"],axis=1)
y=df["Class"]

# %%
# split the data into train and test 
X_train, X_test, y_train, y_test=train_test_split(x,y,train_size=0.8,stratify=y,random_state=45)

# %%
LR_model=LogisticRegression(multi_class="auto")

# %%
LR_model.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Evalution of training data

yp_train=LR_model.predict(X_train)

# %%
train_accuracy=accuracy_score(y_train,yp_train)
print(f"{train_accuracy=}")
# Out:
# train_accuracy=1.0

# %%
yp_test=LR_model.predict(X_test)
test_accuracy=accuracy_score(y_test,yp_test)
print(f"{test_accuracy=}")
# Out:
# test_accuracy=1.0
